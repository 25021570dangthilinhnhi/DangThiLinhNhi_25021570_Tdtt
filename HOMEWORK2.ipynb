# %%
Bài1:
a=int(input("chiều dài"))
b=int(input("chiều rộng"))
S= a*b
P= (a+b)*2
print(P,S)

# %%
Bài2:
a=int(input("bán kính hình tròn"))
PI= 3.14
S= PI*a*a   
C= 2*PI*a
print(S,C)

# %%
Bài3:
a,b,c==map(float,input().split())
if a+b<=c or a+c<=b or b+c<=a:
    print("không phải là ba cạnh của một tam giác")
else:
    print("là ba cạnh của một tam giác")
    if a==b==c:
        print("là tam giác đều")
    elif a==b or a==c or b==c:
        print("là tam giác cân")
    elif a*a+b*b==c*c or a*a+c*c==b*b or b*b+c*c==a*a:
        print("là tam giác vuông")
    else:
        print("là tam giác thường")
        p=(a+b+c)/2
        S=(p*(p-a)*(p-b)*(p-c))**0.5    
        print(p,s)

# %%
Bài4:
a,b=map(float,input().split())
if a==0:
    print("VSN" if b==0 else"VN")
else:
    print(-b/a)

# %%
Bài5:
a,b,c=map(float,input().split())
delta=b*b-4*a*c
if a==0:
    print("x",-c/b if b else "VN")
else:
    d<0:
        print("VN")
    elif d==0:
        print("x1=x2:",-b/(2*a))
    else:
        x1=(-b+d**0.5)/(2*a)
        x2=(-b-d**0.5)/(2*a)
        print("x1:",x1)
        print("x2:",x2)

# %%
Bài6:
a,b,c,d=map(float,input().split())
print(max(a,b,c,d))

# %%
Bài7:
a,b,c,d=map(float,input().split())
print(min(a,b,c,d))

# %%
Bài8:

# %%
Bài9:
x=int(input("nhập số giây"))
h=x//3600
m=(x%3600)//60
s=x%60 
print(h,m,s)

# %%
Bài10:
x0=float(input("hoành độ tâm"))
y0=float(input("tung độ tâm"))
r=float(input("bán kính"))
a=float(input("hoành độ điểm A"))
b=float(input("tung độ điểm A"))
if r**2=(x0-a)**2+(y0-b)**2:
    print("điểm A nằm trên đường tròn")
else:
    print("điểm A không nằm trên đường tròn")

# %%
Bài11:
x=float(input())
y=float(input())
print(x*y)
