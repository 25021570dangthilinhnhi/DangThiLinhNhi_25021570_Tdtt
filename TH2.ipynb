# %%
W2A1:
print("Hello, World!")

# %%
W2A2:
a=input()
print("Hello a")

# %%
W2A3:
a,b=map(int,input().split())
print(a+b,a-b,a*b,a//b,a%b,"%.2f"%(a/b))

# %%
W2A4:
a1,b1,c1,a2,b2,a3=map(int,input().split())
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(round(TB,1))

# %%
W2A5:
a,b=map(int,input().split())
print(a**b)

# %%
W2A6:
a=input()
print(ord(a))
a=a.upper()
print(a)

# %%
W2A7:
A=((13**2)*3)+5
B=13**2*3+5
print(A)
print(B)

# %%
W2A8:
C=int(input())
F=(9/5*C)+32
print(round(F,2))

# %%
W2A9:
x=float(input("nhap gia dong ho"))
shipping=10
tax_export=0.30*x
total=x+shipping+tax_export+tax_export
print(round(total,2))

# %%
W2A10:
a,b,c=input().split()
print(c,b,a)

# %%
W2A11:
h=int(input())
m=int(input())
print(h*3600+m*60)

# %%
W2A12:
n=int(input())
print(6*n*n)

# %%
W2A13:
a=int(input())
b=int(input())
print((a*b)%10)

# %%
W2A14:
a=int(input())
b=int(input())
a,b=b,a
print(a,b)

# %%
W2A15:
n=int(input())
print(3*n*(n-1)+1)

# %%
W2A16:
print("Spring")
print("Summer")
print("Autumn")
print("Winter")

print("Spring\nSummer\nAutumn\nWinter")

# %%
W2A17:
print("  * ")
print(" *** ")
print("*****")

# %%
W2A18:
print("### ##   ### ###")
print(" #  #  #  #   # ")
print(" #  #   # #   # ")
print(" #  #  #  #   # ")
print(" #  # #   #   # ")

# %%
W2A19:
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")

# %%
W2A20:
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")

# %%
W2A21:
for_in range(10):
    print("Hello, World!")

# %%
Bài1:
n=int(input())
print(2*n)

# %%
Bài2:
a=float(input())
b=float(input())
pi=3.14
r=a/2
s=a*b-pi*r*r
print(round(s,2))

# %%
Bài3:
c=input()
if c.isupper():
    print(c.lower())
else:
    print(c.upper())

# %%
Bài4:
c=input()
if c.isalpha():
    print(f"{c} là kí tự alphabet")
else:
    print(f"{c} không phải là kí tự alphabet")

# %%
Bài5:

# %%
Bài6:
a=float(input())
b=float(input())
c=float(input())
if a+b>c and a+c>b and b+c>a:
    p=(a+b+c)/2
    print(round(p*(p-a)*(p-b)*(p-c)),1)
else:
    print("khong phai 3 canh cua tam giac")
